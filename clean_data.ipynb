# %% [markdown]
# # Data exploration, cleaning, transformation and analysis.

# %% [markdown]
# ## Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import matplotlib.pyplot as plt

# %% [markdown]
# ## Import CSV file

# %%
### Import CSV

jobs_usa = pd.read_csv('linkedin-jobs-usa.csv')

# %% [markdown]
# ### Basic exploration

# %%
# Knowing the numbers of rows and columns
jobs_usa.shape
# Out:
# (2845, 9)

# %%
# Display the firts 5 rows of the dataset
jobs_usa.head()
# Out:
#                             title                   company  \
# 0  Data Analyst - Recent Graduate                    PayPal
# 1  Data Analyst - Recent Graduate                    PayPal
# 2                    Data Analyst                    PayPal
# 3                    Data Analyst                    PayPal
# 4        Entry-Level Data Analyst  The Federal Savings Bank
#
#                                          description onsite_remote salary  \
# 0  At PayPal (NASDAQ: PYPL), we believe that ever...        onsite    NaN
# 1  At PayPal (NASDAQ: PYPL), we believe that ever...        onsite    NaN
# 2  At PayPal (NASDAQ: PYPL), we believe that ever...        onsite    NaN
# 3  At PayPal (NASDAQ: PYPL), we believe that ever...        onsite    NaN
# 4  The Federal Savings Bank, a national bank and ...        onsite    NaN
#
#                      location  \
# 0  Buffalo-Niagara Falls Area
# 1                San Jose, CA
# 2        Texas, United States
# ...

# %%
jobs_usa.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2845 entries, 0 to 2844
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   title          2845 non-null   object
#  1   company        2845 non-null   object
#  2   description    2845 non-null   object
#  3   onsite_remote  2845 non-null   object
#  4   salary         929 non-null    object
#  5   location       2845 non-null   object
#  6   criteria       2845 non-null   object
#  7   posted_date    2845 non-null   object
#  8   link           2845 non-null   object
# dtypes: object(9)
# memory usage: 200.2+ KB

# %%
jobs_usa.describe()
# Out:
#                title company  \
# count           2845    2845
# unique            37     171
# top     Data Analyst  PayPal
# freq            2110     499
#
#                                               description onsite_remote  \
# count                                                2845          2845
# unique                                                199             3
# top     At PayPal (NASDAQ: PYPL), we believe that ever...        remote
# freq                                                  309           970
#
#                                                salary       location  \
# count                                             929           2845
# unique                                             45            112
# top     $50.00\r\n            -\r\n            $60.00  United States
# freq                                               89            632
#
#                                                  criteria posted_date  \
# ...

# %%
jobs_usa.drop_duplicates()
# Out:
#                                title                   company  \
# 0     Data Analyst - Recent Graduate                    PayPal
# 1     Data Analyst - Recent Graduate                    PayPal
# 2                       Data Analyst                    PayPal
# 3                       Data Analyst                    PayPal
# 4           Entry-Level Data Analyst  The Federal Savings Bank
# ...                              ...                       ...
# 2840             Junior Data Analyst        Iris Software Inc.
# 2841              Data Analyst (SQL)             Marwood Group
# 2842                    Data Analyst        SmartSense by Digi
# 2843                    Data Analyst            Synergy Search
# 2844                    Data Analyst            Insight Global
#
#                                             description onsite_remote  \
# 0     At PayPal (NASDAQ: PYPL), we believe that ever...        onsite
# ...

# %% [markdown]
# ## Handling null values

# %% [markdown]
# **First option**: remove all rows that contain at least 1 null value.

# %%
df_without_null = jobs_usa.dropna()

# %%
df_without_null.shape
# Out:
# (929, 9)

# %%
df_without_null
# Out:
#                     title                      company  \
# 8            Data Analyst              London Approach
# 24           Data Analyst  Eva Garland Consulting, LLC
# 35           Data Analyst              London Approach
# 61           Data Analyst              London Approach
# 88           Data Analyst              London Approach
# ...                   ...                          ...
# 2834  Junior Data Analyst               Insight Global
# 2836         Data Analyst                  Gridiron IT
# 2841   Data Analyst (SQL)                Marwood Group
# 2843         Data Analyst               Synergy Search
# 2844         Data Analyst               Insight Global
#
#                                             description onsite_remote  \
# 8     The ideal candidate for the Data Analyst/Finan...        onsite
# 24    Reporting to the Director of Operations, the D...        onsite
# 35    The ideal candidate for the Data Analyst/Finan...        onsite
# ...

# %% [markdown]
# **Second option**: remove all columns that contain at least 1 null value.

# %%
df_without_null_columns = jobs_usa.dropna(axis=1)

# %%
df_without_null_columns.shape
# Out:
# (2845, 8)

# %%
df_without_null_columns
# Out:
#                                title                   company  \
# 0     Data Analyst - Recent Graduate                    PayPal
# 1     Data Analyst - Recent Graduate                    PayPal
# 2                       Data Analyst                    PayPal
# 3                       Data Analyst                    PayPal
# 4           Entry-Level Data Analyst  The Federal Savings Bank
# ...                              ...                       ...
# 2840             Junior Data Analyst        Iris Software Inc.
# 2841              Data Analyst (SQL)             Marwood Group
# 2842                    Data Analyst        SmartSense by Digi
# 2843                    Data Analyst            Synergy Search
# 2844                    Data Analyst            Insight Global
#
#                                             description onsite_remote  \
# 0     At PayPal (NASDAQ: PYPL), we believe that ever...        onsite
# ...

# %% [markdown]
# ## Transformation of NaN values

# %% [markdown]
# **First option**: parsing of the numerical column 'salary' using the mean.

# %%
df_without_null['salary']
# Out:
# 8       $100,000.00\r\n            -\r\n            $1...
# 24      $50,000.00\r\n            -\r\n            $55...
# 35      $100,000.00\r\n            -\r\n            $1...
# 61      $100,000.00\r\n            -\r\n            $1...
# 88      $100,000.00\r\n            -\r\n            $1...
#                               ...
# 2834        $30.00\r\n            -\r\n            $33.00
# 2836    $120,000.00\r\n            -\r\n            $1...
# 2841    $75,000.00\r\n            -\r\n            $95...
# 2843    $85,000.00\r\n            -\r\n            $95...
# 2844    $130,000.00\r\n            -\r\n            $1...
# Name: salary, Length: 929, dtype: object

# %%
# Extract de numerical float value of the salary

df_without_null['salaries_numerical'] = df_without_null['salary'].replace('[^\d.]', '', regex=True).str.extract('(\d+)').astype(float)
# Out:
# C:\Users\jdcha\AppData\Local\Temp\ipykernel_5032\2231226944.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_without_null['salaries_numerical'] = df_without_null['salary'].replace('[^\d.]', '', regex=True).str.extract('(\d+)').astype(float)

# %%
df_without_null['salaries_numerical']
# Out:
# 8       100000.0
# 24       50000.0
# 35      100000.0
# 61      100000.0
# 88      100000.0
#           ...
# 2834        30.0
# 2836    120000.0
# 2841     75000.0
# 2843     85000.0
# 2844    130000.0
# Name: salaries_numerical, Length: 929, dtype: float64

# %%
# Analysis of the new numerical salary row
df_without_null['salaries_numerical'].describe()
# Out:
# count       929.000000
# mean      47949.630786
# std       47330.459576
# min          22.000000
# 25%          40.000000
# 50%       60000.000000
# 75%       85000.000000
# max      130000.000000
# Name: salaries_numerical, dtype: float64

# %%
# Create boxplot
plt.boxplot(df_without_null['salaries_numerical'])

plt.ylabel('USD Values')
plt.xlabel('Salary')
plt.title('Boxplot')

plt.show()

# %%
# Create histogram
plt.hist(df_without_null['salaries_numerical'], alpha=0.7)

plt.ylabel('Frecuency')
plt.xlabel('Salary')
plt.title('Histogram')

plt.show()

# %%
# Eliminate salary values less than 20000
df_without_null = df_without_null[df_without_null['salaries_numerical'] >= 20000]

# %%
df_without_null['salaries_numerical']
# Out:
# 8       100000.0
# 24       50000.0
# 35      100000.0
# 61      100000.0
# 88      100000.0
#           ...
# 2826     73036.0
# 2836    120000.0
# 2841     75000.0
# 2843     85000.0
# 2844    130000.0
# Name: salaries_numerical, Length: 498, dtype: float64

# %%
df_without_null['salaries_numerical'].describe()
# Out:
# count       498.000000
# mean      89169.196787
# std       22625.837194
# min       50000.000000
# 25%       73036.000000
# 50%       80000.000000
# 75%      100000.000000
# max      130000.000000
# Name: salaries_numerical, dtype: float64

# %%
#New boxplot
plt.boxplot(df_without_null['salaries_numerical'])

plt.ylabel('USD Values')
plt.xlabel('Salary')
plt.title('Boxplot')

plt.show()

# %%
# New histogram
plt.hist(df_without_null['salaries_numerical'])

plt.ylabel('Frequency')
plt.xlabel('Salary')
plt.title('Histogram')

plt.show()

# %%
# Checking the value of the average salary
df_without_null['salaries_numerical'].mean()
# Out:
# np.float64(89169.1967871486)

# %%
# Fill new salaries column
df_with_new_salaries = df_without_null.fillna(df_without_null['salaries_numerical'].mean())

# %%
df_with_new_salaries
# Out:
#                    title                      company  \
# 8           Data Analyst              London Approach
# 24          Data Analyst  Eva Garland Consulting, LLC
# 35          Data Analyst              London Approach
# 61          Data Analyst              London Approach
# 88          Data Analyst              London Approach
# ...                  ...                          ...
# 2826        Data Analyst                         IKEA
# 2836        Data Analyst                  Gridiron IT
# 2841  Data Analyst (SQL)                Marwood Group
# 2843        Data Analyst               Synergy Search
# 2844        Data Analyst               Insight Global
#
#                                             description onsite_remote  \
# 8     The ideal candidate for the Data Analyst/Finan...        onsite
# 24    Reporting to the Director of Operations, the D...        onsite
# 35    The ideal candidate for the Data Analyst/Finan...        onsite
# ...
